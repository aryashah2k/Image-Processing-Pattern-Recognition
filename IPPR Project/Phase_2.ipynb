# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import os
import pandas as pd

# %%
dataset_path = '/content/drive/MyDrive/ultrasound_breast_classification/train/'
for folder in ['benign', 'malignant']:
    folder_path = os.path.join(dataset_path, folder)
    for filename in os.listdir(folder_path):
        if filename.endswith('.png'):
            img = cv2.imread(os.path.join(folder_path, filename), 0)
            eq_img = cv2.equalizeHist(img)

            fig, axs = plt.subplots(1, 2, figsize=(10, 5))

            axs[0].imshow(img, cmap='gray')
            axs[0].set_title('Original')

            axs[1].imshow(eq_img, cmap='gray')
            axs[1].set_title('Equalized')

            plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-ea10a1a45d31> in <module>
#      15             axs[1].set_title('Equalized')
#      16
# ---> 17             plt.show()
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/pyplot.py in show(*args, **kwargs)
#     385     """
#     386     _warn_if_gui_out_of_main_thread()
# --> 387     return _get_backend_mod().show(*args, **kwargs)
#     388
#     389
#
# /usr/local/lib/python3.9/dist-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ...
